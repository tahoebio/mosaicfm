# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
models = [
    "pca",
    "mosaicfm-70m-pretrained",
    "mosaicfm-70m-adapted",
    "mosaicfm-70m-from-scratch",
    "mosaicfm-70m-tahoe",
    "mosaicfm-70m-merged",
    "mosaicfm-v2-1_3b-merged"
]

# %% [markdown]
# ### mosaic, regression

# %%
results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/mosaic_regression_{m}.csv") for m in models])
results
# Out:
#                                              condition  \
# 0                      [('Cetuximab', 0.068596, 'uM')]
# 1                      [('Cetuximab', 0.068596, 'uM')]
# 2                      [('Cetuximab', 0.068596, 'uM')]
# 3                      [('Cetuximab', 0.068596, 'uM')]
# 4                         [('Encorafenib', 0.1, 'uM')]
# ..                                                 ...
# 359  [('Adagrasib', 0.005, 'uM'), ('LY3200882', 0.5...
# 360  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 361  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 362  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 363  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
#
#                    embedding        r2  permuted  permuted-iter
# 0                        pca -0.114964     False              0
# 1                        pca -0.392099      True              1
# 2                        pca -0.191552      True              2
# 3                        pca -0.067275      True              3
# 4                        pca -0.604864     False              0
# ..                       ...       ...       ...            ...
# 359  mosaicfm-v2-1_3b-merged -0.065533      True              3
# 360  mosaicfm-v2-1_3b-merged  0.097916     False              0
# 361  mosaicfm-v2-1_3b-merged -0.092048      True              1
# 362  mosaicfm-v2-1_3b-merged -0.063592      True              2
# 363  mosaicfm-v2-1_3b-merged -0.031199      True              3
#
# [2548 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="r2", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="r2", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["r2"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta"}).sort_values(by="delta")
ax = sns.barplot(data=diffs, x="delta", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["r2"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["r2"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"r2": "frac"}).sort_values(by="frac")
ax = sns.barplot(data=fracs, x="frac", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac"]], fontsize=10, padding=-37, color="white")
plt.show()

# %% [markdown]
# ### mosaic, classification

# %%
results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/mosaic_classification_{m}.csv") for m in models])
results
# Out:
#                                              condition  \
# 0                      [('Cetuximab', 0.068596, 'uM')]
# 1                      [('Cetuximab', 0.068596, 'uM')]
# 2                      [('Cetuximab', 0.068596, 'uM')]
# 3                      [('Cetuximab', 0.068596, 'uM')]
# 4                         [('Encorafenib', 0.1, 'uM')]
# ..                                                 ...
# 359  [('Adagrasib', 0.005, 'uM'), ('LY3200882', 0.5...
# 360  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 361  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 362  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
# 363  [('LY3200882', 0.1, 'uM'), ('Adagrasib', 0.005...
#
#                    embedding     auroc     auprc  permuted  permuted-iter
# 0                        pca  0.508929  0.600260     False              0
# 1                        pca  0.588542  0.656222      True              1
# 2                        pca  0.462798  0.517768      True              2
# 3                        pca  0.462798  0.527073      True              3
# 4                        pca  0.335556  0.457882     False              0
# ..                       ...       ...       ...       ...            ...
# 359  mosaicfm-v2-1_3b-merged  0.527407  0.562509      True              3
# 360  mosaicfm-v2-1_3b-merged  0.673363  0.739507     False              0
# 361  mosaicfm-v2-1_3b-merged  0.575893  0.605873      True              1
# 362  mosaicfm-v2-1_3b-merged  0.530506  0.558920      True              2
# 363  mosaicfm-v2-1_3b-merged  0.622024  0.617648      True              3
#
# [2548 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auroc", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auroc", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["auroc"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta_auroc"}).sort_values(by="delta_auroc")
ax = sns.barplot(data=diffs, x="delta_auroc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta_auroc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["auroc"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["auroc"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"auroc": "frac_auroc"}).sort_values(by="frac_auroc")
ax = sns.barplot(data=fracs, x="frac_auroc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac_auroc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auprc", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auprc", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["auprc"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta_auprc"}).sort_values(by="delta_auprc")
ax = sns.barplot(data=diffs, x="delta_auprc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta_auprc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["auprc"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["auprc"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"auprc": "frac_auprc"}).sort_values(by="frac_auprc")
ax = sns.barplot(data=fracs, x="frac_auprc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac_auprc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %% [markdown]
# ### prism, regression

# %%
results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism_regression_{m}.csv") for m in models])
results
# Out:
#                                         condition                embedding  \
# 0                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 1                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 2                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 3                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 4                BRD-A00100033-001-08-9::2.5::HTS                      pca
# ...                                           ...                      ...
# 18739         BRD-K99919177-001-01-3::2.5::MTS004  mosaicfm-v2-1_3b-merged
# 18740  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
# 18741  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
# 18742  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
# 18743  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
#
#              r2  permuted  permuted-iter
# 0     -0.069236     False              0
# 1     -0.114002      True              1
# 2     -0.103686      True              2
# 3     -0.083433      True              3
# 4     -0.065745     False              0
# ...         ...       ...            ...
# 18739 -0.039639      True              3
# 18740 -0.059370     False              0
# 18741 -0.103779      True              1
# 18742 -0.063932      True              2
# 18743 -0.062400      True              3
#
# [131208 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="r2", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="r2", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["r2"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta"}).sort_values(by="delta")
ax = sns.barplot(data=diffs, x="delta", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["r2"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["r2"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"r2": "frac"}).sort_values(by="frac")
ax = sns.barplot(data=fracs, x="frac", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac"]], fontsize=10, padding=-37, color="white")
plt.show()

# %% [markdown]
# ### prism, classification

# %%
results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism_classification_{m}.csv") for m in models])
results
# Out:
#                                         condition                embedding  \
# 0                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 1                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 2                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 3                BRD-A00077618-236-07-6::2.5::HTS                      pca
# 4                BRD-A00100033-001-08-9::2.5::HTS                      pca
# ...                                           ...                      ...
# 18559         BRD-K99919177-001-01-3::2.5::MTS004  mosaicfm-v2-1_3b-merged
# 18560  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
# 18561  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
# 18562  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
# 18563  BRD-M63173034-001-03-6::2.64076472::MTS004  mosaicfm-v2-1_3b-merged
#
#           auroc     auprc  permuted  permuted-iter
# 0      0.494975  0.489460     False              0
# 1      0.521710  0.528164      True              1
# 2      0.529079  0.527139      True              2
# 3      0.498899  0.487563      True              3
# 4      0.594728  0.789054     False              0
# ...         ...       ...       ...            ...
# 18559  0.474419  0.997558      True              3
# 18560  0.445894  0.265021     False              0
# 18561  0.437297  0.264579      True              1
# 18562  0.524633  0.305815      True              2
# 18563  0.475193  0.295658      True              3
#
# [129948 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auroc", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auroc", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["auroc"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta_auroc"}).sort_values(by="delta_auroc")
ax = sns.barplot(data=diffs, x="delta_auroc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta_auroc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["auroc"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["auroc"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"auroc": "frac_auroc"}).sort_values(by="frac_auroc")
ax = sns.barplot(data=fracs, x="frac_auroc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac_auroc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auprc", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auprc", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["auprc"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta_auprc"}).sort_values(by="delta_auprc")
ax = sns.barplot(data=diffs, x="delta_auprc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta_auprc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["auprc"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["auprc"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"auprc": "frac_auprc"}).sort_values(by="frac_auprc")
ax = sns.barplot(data=fracs, x="frac_auprc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac_auprc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %% [markdown]
# ### prism-sec, regression

# %%
results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism-sec_regression_{m}.csv") for m in models])
results
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism-sec_regression_{m}.csv") for m in models])
#       2 results
#
# Cell In[31], line 1, in <listcomp>(.0)
# ----> 1 results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism-sec_regression_{m}.csv") for m in models])
#       2 results
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/vevo/umair/data/sens-pred/results/prism-sec_regression_mosaicfm-v2-1_3b-merged.csv'

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="r2", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="r2", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["r2"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta"}).sort_values(by="delta")
ax = sns.barplot(data=diffs, x="delta", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["r2"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["r2"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"r2": "frac"}).sort_values(by="frac")
ax = sns.barplot(data=fracs, x="frac", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac"]], fontsize=10, padding=-37, color="white")
plt.show()

# %% [markdown]
# ### prism-sec, classification

# %%
results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism-sec_classification_{m}.csv") for m in models])
results
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism-sec_classification_{m}.csv") for m in models])
#       2 results
#
# Cell In[32], line 1, in <listcomp>(.0)
# ----> 1 results = pd.concat([pd.read_csv(f"/vevo/umair/data/sens-pred/results/prism-sec_classification_{m}.csv") for m in models])
#       2 results
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /vevo/umair/miniforge3/envs/mosaicfm/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/vevo/umair/data/sens-pred/results/prism-sec_classification_mosaicfm-v2-1_3b-merged.csv'

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auroc", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auroc", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["auroc"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta_auroc"}).sort_values(by="delta_auroc")
ax = sns.barplot(data=diffs, x="delta_auroc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta_auroc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["auroc"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["auroc"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"auroc": "frac_auroc"}).sort_values(by="frac_auroc")
ax = sns.barplot(data=fracs, x="frac_auroc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac_auroc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auprc", y="embedding", hue="permuted", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.boxplot(data=results, x="auprc", y="embedding", hue="permuted-iter", order=models, ax=ax)
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
medians = results.groupby(["embedding", "permuted"])["auprc"].median().unstack()
diffs = (medians[False] - medians[True]).reset_index().rename(columns={0: "delta_auprc"}).sort_values(by="delta_auprc")
ax = sns.barplot(data=diffs, x="delta_auprc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in diffs["delta_auprc"]], fontsize=10, padding=-37, color="white")
plt.show()

# %%
thresholds = results[results["permuted"] == True].groupby("embedding")["auprc"].quantile(0.95)
fracs = (results[results["permuted"] == False].groupby("embedding")["auprc"].apply(lambda x: (x > thresholds[x.name]).mean())).reset_index().rename(columns={"auprc": "frac_auprc"}).sort_values(by="frac_auprc")
ax = sns.barplot(data=fracs, x="frac_auprc", y="embedding")
ax.bar_label(ax.containers[0], labels=[f"{x:.4f}" for x in fracs["frac_auprc"]], fontsize=10, padding=-37, color="white")
plt.show()
